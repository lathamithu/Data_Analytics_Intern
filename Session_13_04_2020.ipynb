# %% [markdown]
# <a href="https://colab.research.google.com/github/lathamithu/Data_Analytics_Intern/blob/master/Session_13_04_2020.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt
t = [1,2,3,4,5,6,7,8,9]
A1 = [1,2,5,2,1,2,5,2,1]
A2 = [2,3,6,13,2,3,6,3,2]
plt.plot(t,A1,label="data1")
plt.plot(t,A2,label="data2")
plt.xlabel("time")
plt.ylabel("amplitude")
plt.legend()
plt.show()

# %%
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import axes3d
fig = plt.figure()
ax = fig.add_subplot(111,projection='3d')
x,y,z = axes3d.get_test_data()
for q in x:
  print(q)
print(len(x))
ax.plot_wireframe(x,y,z,rstride = 2,cstride=2)
ax.set_xlabel('x-axis')
ax.set_ylabel('y-xis')
ax.set_zlabel('z-axis')
plt.title("wireframe")
plt.tight_layout()
plt.show()
# Out:
# [-3.0000000e+01 -2.9500000e+01 -2.9000000e+01 -2.8500000e+01
#  -2.8000000e+01 -2.7500000e+01 -2.7000000e+01 -2.6500000e+01
#  -2.6000000e+01 -2.5500000e+01 -2.5000000e+01 -2.4500000e+01
#  -2.4000000e+01 -2.3500000e+01 -2.3000000e+01 -2.2500000e+01
#  -2.2000000e+01 -2.1500000e+01 -2.1000000e+01 -2.0500000e+01
#  -2.0000000e+01 -1.9500000e+01 -1.9000000e+01 -1.8500000e+01
#  -1.8000000e+01 -1.7500000e+01 -1.7000000e+01 -1.6500000e+01
#  -1.6000000e+01 -1.5500000e+01 -1.5000000e+01 -1.4500000e+01
#  -1.4000000e+01 -1.3500000e+01 -1.3000000e+01 -1.2500000e+01
#  -1.2000000e+01 -1.1500000e+01 -1.1000000e+01 -1.0500000e+01
#  -1.0000000e+01 -9.5000000e+00 -9.0000000e+00 -8.5000000e+00
#  -8.0000000e+00 -7.5000000e+00 -7.0000000e+00 -6.5000000e+00
#  -6.0000000e+00 -5.5000000e+00 -5.0000000e+00 -4.5000000e+00
#  -4.0000000e+00 -3.5000000e+00 -3.0000000e+00 -2.5000000e+00
#  -2.0000000e+00 -1.5000000e+00 -1.0000000e+00 -5.0000000e-01
# ...

# %%
from google.colab import auth
auth.authenticate_user()

import gspread
from oauth2client.client import GoogleCredentials

gc = gspread.authorize(GoogleCredentials.get_application_default())

# %%
sh = gc.create('thiru')

# %%
worksheet = gc.open('thiru').sheet1
cell_list = worksheet.range('A1:B5')
for cell in cell_list:
  cell.value = input()
worksheet.update_cells(cell_list)

# %%
import numpy as np
import matplotlib.pyplot as plt
import statsmodels.api as sm
import pandas as pd
# Out:
# /usr/local/lib/python3.6/dist-packages/statsmodels/tools/_testing.py:19: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   import pandas.util.testing as tm

# %%
data = pd.read_csv('sample_dataset.csv')
data.head()
# Out:
#     SAT   GPA
# 0  1714  2.40
# 1  1664  2.52
# 2  1760  2.54
# 3  1685  2.74
# 4  1693  2.83

# %%
i = 2
x = data.iloc[:,0]
y = data.iloc[:,1]
print (x)
print(y)
# Out:
# 0     1714
# 1     1664
# 2     1760
# 3     1685
# 4     1693
#       ...
# 79    1936
# 80    1810
# 81    1987
# 82    1962
# 83    2050
# Name: SAT, Length: 84, dtype: int64
# 0     2.40
# 1     2.52
# 2     2.54
# 3     2.74
# 4     2.83
#       ...
# 79    3.71
# 80    3.71
# 81    3.73
# 82    3.76
# 83    3.81
# Name: GPA, Length: 84, dtype: float64

# %%
worksheet = gc.open('sample_dataset').sheet1
i = 2
y=[]
x1=[]
while i<=85:
  x1.append(int(worksheet.cell(i,1).value))
  i=i+1
i=2
while i<=85:
  y.append(float(worksheet.cell(i,2).value))
  i=i+1 
print(x1)

# %%
plt.scatter(x,y)
plt.ylabel('GPA',fontsize=20)
plt.xlabel('SAT',fontsize=20)
plt.show()

# %%
x1 = sm.add_constant(x)
results = sm.OLS(y,x1).fit()
results.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                    GPA   R-squared:                       0.406
# Model:                            OLS   Adj. R-squared:                  0.399
# Method:                 Least Squares   F-statistic:                     56.05
# Date:                Tue, 14 Apr 2020   Prob (F-statistic):           7.20e-11
# Time:                        17:37:33   Log-Likelihood:                 12.672
# No. Observations:                  84   AIC:                            -21.34
# Df Residuals:                      82   BIC:                            -16.48
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.2750      0.409      0.673      0.503      -0.538       1.088
# ...

# %%
plt.scatter(x,y)
yhat=[]
for q in x:
    yhat.append(0.2750+0.0017*q)

fig=plt.plot(x,yhat,lw=3, c='orange' , label='regressionline')
plt.ylabel('GPA',fontsize=20)
plt.xlabel('SAT',fontsize=20)
plt.show()

# %%
plt.scatter(x,y)
yhat=[]
for q in x:
    yhat.append(0+0.0017*q)

fig=plt.plot(x,yhat,lw=3, c='green' , label='regressionline')
plt.ylabel('GPA',fontsize=20)
plt.xlabel('SAT',fontsize=20)
plt.show()
